# %% [markdown]
# ## ESTUDIO PRUNTOS CRITICOS PARA DIALUX

# %%
import module_AoiGrids as gr
import module_Cell as cell

# %% [markdown]
# ### SOLSTICIO INVIERNO MOMENTO DE MAYOR IRRADIANCIA 13h: AOI 35º DESP 1,6

# %%
aoi=gr.spot_grid(10)
cell_circular_grid=cell.circular_cell(0.6, 0.69,0)
gr.plot_grid('área célula fotovoltaica',cell_circular_grid)
gr.plot_grid('spot',aoi)
area_illum,area_elect= cell.areas_intersection(aoi,cell_circular_grid)
gr.plot_grid('area_illum',area_illum)
gr.plot_grid('area_elec',area_elect)

# %% [markdown]
# ### EQUINOCCIO PRIMAVERA Y OTOÑO MOMENTO DE MAYOR IRRADIANCIA 13h: AOI 10º DESP 0,82

# %%
aoi=gr.spot_grid(10)
cell_circular_grid=cell.circular_cell(0.6, 0.7,0)
gr.plot_grid('área célula fotovoltaica',cell_circular_grid)
gr.plot_grid('spot',aoi)
area_illum,area_elect= cell.areas_intersection(aoi,cell_circular_grid)
gr.plot_grid('area_illum',area_illum)
gr.plot_grid('area_elec',area_elect)

# %% [markdown]
# ### SOLSTICIO VERANO MOMENTO DE MAYOR IRRADIANCIA 14h: AOI 15º DESP 1,6

# %%
aoi=gr.spot_grid(15)
cell_circular_grid=cell.circular_cell(0.6, 1.6,0)
gr.plot_grid('área célula fotovoltaica',cell_circular_grid)
gr.plot_grid('spot',aoi)
area_illum,area_elect= cell.areas_intersection(aoi,cell_circular_grid)
gr.plot_grid('area_illum',area_illum)
gr.plot_grid('area_elec',area_elect)

# %% [markdown]
# ### MOMENTO DE MENORES IRRADIANCIA: AOI 50º  SIN INTERSECCIÓN

# %%
aoi=gr.spot_grid(50)
cell_circular_grid=cell.circular_cell(0.6, 0,0)
gr.plot_grid('área célula fotovoltaica',cell_circular_grid)
gr.plot_grid('spot',aoi)
area_illum,area_elect= cell.areas_intersection(aoi,cell_circular_grid)
gr.plot_grid('area_illum',area_illum)
gr.plot_grid('area_elec',area_elect)
