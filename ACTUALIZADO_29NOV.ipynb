# %% [markdown]
# # TRABAJO CON MATRICES

# %%
import module_Cell as cell
import module_AoiGrids as gr
import pandas as pd

# %% [markdown]
# Mostramos como se van a tratar los datos obtenidos

# %%
for i in range(0,65,5):
    aoi=gr.spot_grid(i)
    gr.plot_grid(i,aoi)

# %% [markdown]
# La interpolación se ha hecho buscando el punto medio de las dos matrices de datos entre el aoi pedido. Interpolando estos puntos medios obtenemos el punto medio de la nueva matriz. Esa matriz será la interpolación de las matrices de datos que se tienen interpolados cada uno de sus numeros colocando el punto medio de estas en el punto medio de la nueva matriz

# %%
for i in range(0,65,1):
    aoi=gr.spot_grid(i)
    gr.plot_grid(i,aoi)
# Out:
# AOI FUERA DE ESTUDIO
# AOI FUERA DE ESTUDIO
# AOI FUERA DE ESTUDIO
# AOI FUERA DE ESTUDIO

# %% [markdown]
# Para poder trabajar entre la itnersección de estas áreas de spot y el área de la celula. Creamos una matriz con 1's que formen la forma deseada. Se han creado dos funciones, una para celulas circulares y otra rectangulares. Ambas ellas se puede situar su lugar sobre el plano introduciendo las coordendas de desfase respecto al centro de la matriz

# %% [markdown]
# El primer valor a introducir es el radio y los otros dos el desfase. En la rectangular los dos primeros son los lados y despues el defase

# %%
cell_circular_grid=cell.circular_cell(0.5, 0,0 )
cell_rectangular_grid=cell.rectangular_cell(1,1.5, 0, 0)
gr.plot_grid('circular',cell_circular_grid)
gr.plot_grid('rectangular',cell_rectangular_grid)

# %% [markdown]
# Creamos una función de intersección que nos devuelva la matriz de iluminación y la de electricidad

# %%
aoi=gr.spot_grid(0)
area_illum,area_elect= cell.areas_intersection(aoi,cell_circular_grid)
gr.plot_grid('area_illum',area_illum)
gr.plot_grid('area_elec',area_elect)
