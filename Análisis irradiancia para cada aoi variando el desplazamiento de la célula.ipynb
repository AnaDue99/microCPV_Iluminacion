# %% [markdown]
# # Irradiancia variando el desplazamiento para cada aoi

# %% [markdown]
# Estudiamos para cada aoi como se comporta la irradiancia dependiendo del desplazamiento de la celula

# %%
import module_Cell as cell
import module_AoiGrids as gr
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import InterpolatedUnivariateSpline as interp
caracteristics_module={    
    'tilt':0,
    'surface_azimuth':180,
    'radius':0.6
    }

# %%
irradiance_aoi_0=[]
irradiance_aoi_5=[]
irradiance_aoi_10=[]
irradiance_aoi_15=[]
irradiance_aoi_20=[]
irradiance_aoi_25=[]
irradiance_aoi_30=[]
irradiance_aoi_35=[]
irradiance_aoi_40=[]
irradiance_aoi_45=[]
irradiance_aoi_50=[]
irradiance_aoi_55=[]
irradiance_aoi_60=[]

# %% [markdown]
# Hacemos el calculo principal, desplazando en un sentido la celula desde 0 a 3mm en un paso de 0.01 mm

# %%
desp=np.arange(-3, 3, 0.01)

for i in desp:
    irradiance_aoi_0.append(cell.irradiance_cell(caracteristics_module['radius'], i, 0, 0))
    irradiance_aoi_5.append(cell.irradiance_cell(caracteristics_module['radius'], i, 0, 5))
    irradiance_aoi_10.append(cell.irradiance_cell(caracteristics_module['radius'], i, 0, 10))
    irradiance_aoi_15.append(cell.irradiance_cell(caracteristics_module['radius'], i, 0, 15))
    irradiance_aoi_20.append(cell.irradiance_cell(caracteristics_module['radius'], i, 0, 20))
    irradiance_aoi_25.append(cell.irradiance_cell(caracteristics_module['radius'], i, 0, 25))
    irradiance_aoi_30.append(cell.irradiance_cell(caracteristics_module['radius'], i, 0, 30))
    irradiance_aoi_35.append(cell.irradiance_cell(caracteristics_module['radius'], i, 0, 35))
    irradiance_aoi_40.append(cell.irradiance_cell(caracteristics_module['radius'], i, 0, 40))
    irradiance_aoi_45.append(cell.irradiance_cell(caracteristics_module['radius'], i, 0, 45))
    irradiance_aoi_50.append(cell.irradiance_cell(caracteristics_module['radius'], i, 0, 50))
    irradiance_aoi_55.append(cell.irradiance_cell(caracteristics_module['radius'], i, 0, 55))
    irradiance_aoi_60.append(cell.irradiance_cell(caracteristics_module['radius'], i, 0, 60))

# %% [markdown]
# Vemos todas las rectas de forma conjunta

# %%
plt.plot(desp,irradiance_aoi_0,label='aoi 0')
plt.plot(desp,irradiance_aoi_5,label='aoi 5')
plt.plot(desp,irradiance_aoi_10,label='aoi 10')
plt.plot(desp,irradiance_aoi_15,label='aoi 15')
plt.plot(desp,irradiance_aoi_20,label='aoi 20')
plt.plot(desp,irradiance_aoi_25,label='aoi 25')
plt.plot(desp,irradiance_aoi_30,label='aoi 30')
plt.plot(desp,irradiance_aoi_35,label='aoi 35')
plt.plot(desp,irradiance_aoi_40,label='aoi 40')
plt.plot(desp,irradiance_aoi_45,label='aoi 45')
plt.plot(desp,irradiance_aoi_50,label='aoi 50')
plt.plot(desp,irradiance_aoi_55,label='aoi 55')
plt.plot(desp,irradiance_aoi_60,label='aoi 60')

plt.legend(loc=(1, 0))
plt.xlabel('Desplazamiento[mm]')
plt.ylabel('Irradiance [W/m2]')
plt.title("Muesta irradiancias iluminacion(fuera celula) para distintos AOI y variación desplazamiento")

plt.show()

# %% [markdown]
# Si analizamos un poco podemos agruparlas poco a poco en similud.

# %% [markdown]
# ### El AOI=0º

# %%
plt.plot(desp,irradiance_aoi_0,label='aoi 0')
plt.legend(loc=(1, 0))
plt.xlabel('Desplazamiento[mm]')
plt.ylabel('Irradiance [W/m2]')
plt.title("Muesta irradiancias iluminacion(fuera celula) para distintos AOI y variación desplazamiento")


plt.show()

# %%
irradiance_aoi_60
# Out:
# [32.694825616912304,
#  32.694825616912304,
#  32.694825616912304,
#  32.68381684475176,
#  32.68381684475176,
#  32.68381684475176,
#  32.68381684475176,
#  32.6700199811845,
#  32.6700199811845,
#  32.6700199811845,
#  32.6700199811845,
#  32.65321261103654,
#  32.65321261103654,
#  32.65321261103654,
#  32.65321261103654,
#  32.63311659352004,
#  32.63311659352004,
#  32.63311659352004,
#  32.63311659352004,
#  32.60881663326594,
#  32.60881663326594,
#  32.60881663326594,
#  32.60881663326594,
#  32.57986467365136,
#  32.57986467365136,
#  32.57986467365136,
#  32.57986467365136,
#  32.5482851884244,
#  32.5482851884244,
#  32.5482851884244,
#  32.5482851884244,
#  32.514057869824086,
#  32.514057869824086,
#  32.514057869824086,
#  32.514057869824086,
#  32.473817065600514,
#  32.473817065600514,
#  32.43942517174389,
#  32.45946559332628,
#  32.45946559332628,
#  32.45946559332628,
#  32.45946559332628,
#  32.479537086088584,
#  32.479537086088584,
#  32.479537086088584,
#  32.479537086088584,
#  32.49938252478462,
#  32.49938252478462,
#  32.49938252478462,
#  32.49938252478462,
#  32.519757775105965,
#  32.519757775105965,
#  32.519757775105965,
#  32.519757775105965,
#  32.53961767855163,
#  32.53961767855163,
#  32.53961767855163,
#  32.53961767855163,
#  32.55767858552442,
#  32.55767858552442,
#  32.55767858552442,
#  32.55767858552442,
#  32.57404705129585,
#  32.57404705129585,
#  32.57404705129585,
#  32.57404705129585,
#  32.58972698922142,
#  32.58972698922142,
#  32.58972698922142,
#  32.58972698922142,
#  32.60516437668173,
#  32.60516437668173,
#  32.60516437668173,
#  32.60516437668173,
#  32.62057460343959,
#  32.62057460343959,
#  32.62057460343959,
#  32.62057460343959,
#  32.63485912048887,
#  32.63485912048887,
#  32.63485912048887,
#  32.63485912048887,
#  32.647998938697654,
#  32.647998938697654,
#  32.647998938697654,
#  32.647998938697654,
#  32.66006454577595,
#  32.66006454577595,
#  32.66006454577595,
#  32.66006454577595,
#  32.67152808603205,
#  32.67152808603205,
#  32.67152808603205,
#  32.67152808603205,
#  32.68233594496849,
#  32.68233594496849,
#  32.68233594496849,
#  32.68233594496849,
#  32.69209859475461,
#  32.69209859475461,
#  32.69209859475461,
#  32.69209859475461,
#  32.700231226453695,
#  32.700231226453695,
#  32.700231226453695,
#  32.700231226453695,
#  32.707199420046365,
#  32.707199420046365,
#  32.707199420046365,
#  32.707199420046365,
#  32.713205737479726,
#  32.713205737479726,
#  32.713205737479726,
#  32.713205737479726,
#  32.71840545562294,
#  32.71840545562294,
#  32.71840545562294,
#  32.71840545562294,
#  32.722488130332344,
#  32.722488130332344,
#  32.722488130332344,
#  32.722488130332344,
#  32.72534917816717,
#  32.72534917816717,
#  32.72534917816717,
#  32.72534917816717,
#  32.72711340300272,
#  32.72711340300272,
#  32.72711340300272,
#  32.72711340300272,
#  32.728368323078186,
#  32.728368323078186,
#  32.728368323078186,
#  32.728368323078186,
#  32.729236234253825,
#  32.729236234253825,
#  32.729236234253825,
#  32.729236234253825,
#  32.72981216733237,
#  32.72981216733237,
#  32.72981216733237,
#  32.72981216733237,
#  32.730157682643025,
#  32.730157682643025,
#  32.730157682643025,
#  32.730157682643025,
#  32.730366117292434,
#  32.730366117292434,
#  32.730366117292434,
#  32.730366117292434,
#  32.730513389384534,
#  32.730513389384534,
#  32.730513389384534,
#  32.730513389384534,
#  32.730602714715054]

# %% [markdown]
# Interpolamos con spline: curva polinómica de grado 3 cada punto obtenido. Asi tenemos polinomios que pasan por estos puntos con un polinomio de grado no muy alto

# %%
f_0=interp(desp,irradiance_aoi_0,k=3)
x1=np.linspace(0,3)
y1=f_0(x1)
plt.plot(desp, irradiance_aoi_0, 'x')
plt.plot(x1,y1)

# %% [markdown]
# ### El AOI=5º y 10º

# %%
plt.plot(desp,irradiance_aoi_5,label='aoi 5')
plt.plot(desp,irradiance_aoi_10,label='aoi 10')
plt.legend(loc=(1, 0))
plt.xlabel('Desplazamiento[mm]')
plt.ylabel('Irradiance [W/m2]')
plt.title("Muesta irradiancias iluminacion(fuera celula) para distintos AOI y variación desplazamiento")

plt.show()

# %%
f_5=interp(desp,irradiance_aoi_5,k=3)
f_10=interp(desp,irradiance_aoi_10,k=3)

# %% [markdown]
# ### El AOI=15º

# %%
plt.plot(desp,irradiance_aoi_15,label='aoi 15')
plt.legend(loc=(1, 0))
plt.xlabel('Desplazamiento[mm]')
plt.ylabel('Irradiance [W/m2]')
plt.title("Muesta irradiancias iluminacion(fuera celula) para distintos AOI y variación desplazamiento")

plt.show()

# %%
f_15=interp(desp,irradiance_aoi_15,k=3)

# %% [markdown]
# ### EL AOI= 20º Y 25º

# %%
plt.plot(desp,irradiance_aoi_20,label='aoi 20')
plt.plot(desp,irradiance_aoi_25,label='aoi 25')
plt.legend(loc=(1, 0))
plt.xlabel('Desplazamiento[mm]')
plt.ylabel('Irradiance [W/m2]')
plt.title("Muesta irradiancias iluminacion(fuera celula) para distintos AOI y variación desplazamiento")

plt.show()

# %%
f_20=interp(desp,irradiance_aoi_20,k=3)
f_25=interp(desp,irradiance_aoi_25,k=3)

# %% [markdown]
# ### EL AOI=30º 35º Y 40º

# %%
plt.plot(desp,irradiance_aoi_30,label='aoi 30')
plt.plot(desp,irradiance_aoi_35,label='aoi 35')
plt.plot(desp,irradiance_aoi_40,label='aoi 40')
plt.legend(loc=(1, 0))
plt.xlabel('Desplazamiento[mm]')
plt.ylabel('Irradiance [W/m2]')
plt.title("Muesta irradiancias iluminacion(fuera celula) para distintos AOI y variación desplazamiento")

plt.show()

# %%
f_30=interp(desp,irradiance_aoi_30,k=3)
f_35=interp(desp,irradiance_aoi_35,k=3)
f_40=interp(desp,irradiance_aoi_40,k=3)

# %% [markdown]
# ### EL AOI DE 45º

# %%
plt.plot(desp,irradiance_aoi_45,label='aoi 45')
plt.legend(loc=(1, 0))
plt.xlabel('Desplazamiento[mm]')
plt.ylabel('Irradiance [W/m2]')
plt.title("Muesta irradiancias iluminacion(fuera celula) para distintos AOI y variación desplazamiento")

plt.show()

# %%
f_45=interp(desp,irradiance_aoi_45,k=3)

# %% [markdown]
# ### EL AOI DE 50º Y 55º

# %%
plt.plot(desp,irradiance_aoi_50,label='aoi 50')
plt.plot(desp,irradiance_aoi_55,label='aoi 55')
plt.legend(loc=(1, 0))
plt.xlabel('Desplazamiento[mm]')
plt.ylabel('Irradiance [W/m2]')
plt.title("Muesta irradiancias iluminacion(fuera celula) para distintos AOI y variación desplazamiento")

plt.show()

# %%
f_50=interp(desp,irradiance_aoi_50,k=3)
f_55=interp(desp,irradiance_aoi_55,k=3)

# %% [markdown]
# ### AOI DE 60º

# %%
plt.plot(desp,irradiance_aoi_60,label='aoi 60')
plt.legend(loc=(1, 0))
plt.xlabel('Desplazamiento[mm]')
plt.ylabel('Irradiance [W/m2]')
plt.title("Muesta irradiancias iluminacion(fuera celula) para distintos AOI y variación desplazamiento")

plt.show()

# %%
f_60=interp(desp,irradiance_aoi_60,k=3)

# %%
x=np.linspace(-3,3)
y0=f_0(x)
y5=f_5(x)
y10=f_10(x)
y15=f_15(x)
y20=f_20(x)
y25=f_25(x)
y30=f_30(x)
y35=f_35(x)
y40=f_40(x)
y45=f_45(x)
y50=f_50(x)
y55=f_55(x)
y60=f_60(x)

plt.plot(x,y0,label='aoi 0')
plt.plot(x,y5,label='aoi 5')
plt.plot(x,y10,label='aoi 10')
plt.plot(x,y15,label='aoi 15')
plt.plot(x,y20,label='aoi 20')
plt.plot(x,y25,label='aoi 25')
plt.plot(x,y30,label='aoi 30')
plt.plot(x,y35,label='aoi 35')
plt.plot(x,y40,label='aoi 40')
plt.plot(x,y45,label='aoi 45')
plt.plot(x,y50,label='aoi 50')
plt.plot(x,y55,label='aoi 55')
plt.plot(x,y60,label='aoi 60')

plt.legend(loc=(1, 0))
plt.xlabel('Desplazamiento[mm]')
plt.ylabel('Irradiance [W/m2]')
plt.title("Muesta irradiancias iluminacion(fuera celula) para distintos AOI y variación desplazamiento")

plt.show()

# %% [markdown]
# ## % COMO LA FIGURA DADA

# %%
x=np.linspace(-3,3)
y0=f_0(x)

y10=f_10(x)

y20=f_20(x)

y30=f_30(x)


plt.plot(x,y0*100/110.26,label='aoi 0')

plt.plot(x,y10*100/110.26,label='aoi 10')

plt.plot(x,y20*100/110.26,label='aoi 20')

plt.plot(x,y30*100/110.26,label='aoi 30')



plt.legend(loc=(1, 0))
plt.xlabel('Desplazamiento[mm]')
plt.ylabel('% OUTPUT')
plt.title("Muesta irradiancias iluminacion(fuera celula) para distintos AOI y variación desplazamiento")
ax = plt.gca()
ax.set_xlim([-2.9, 2.9])
ax.set_ylim([0, 110])
plt.show()

# %%
y40=f_40(x)

y50=f_50(x)

y60=f_60(x)

plt.plot(x,y40*100/110.26,label='aoi 40')

plt.plot(x,y50*100/110.26,label='aoi 50')

plt.plot(x,y60*100/110.26,label='aoi 60')
plt.legend(loc=(1, 0))
plt.xlabel('Desplazamiento[mm]')
plt.ylabel('% OUTPUT')
plt.title("Muesta irradiancias iluminacion(fuera celula) para distintos AOI y variación desplazamiento")
ax = plt.gca()
ax.set_xlim([-2.9, 2.9])
ax.set_ylim([0, 110])
plt.show()
